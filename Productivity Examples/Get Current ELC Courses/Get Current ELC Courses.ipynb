# %% [markdown]
# ## Get Current ELC Courses
#
# The Economics Learning Center (ELC) at UCI helps students in Econ 10A/B, Econ 100A/B/C, Econ 15A/B, and Econ 122A/B. This notebook:
#
# 1. Loads a file `Instructor_Emails.csv` containing economics instructor emails and name abbreviations used in UCI's schedule of classes
# 2. Loads and parses a HTML file generated from a Schedule of Classes search for economics courses for the current quarter.
# 3. Identifies which ELC-relevant courses are being offered in the current quarter and the respective instructors.
# 4. Displays instructor emails for easy copy-paste into email client.
# 5. Exports data to a csv file.
#
# To use:
#
# 1. Add instructor names to `Instructor_Emails.csv` as needed
# 2. Set the values of `quarter` and `year`

# %%
# Current quarter
quarter = 'Fall'

# Current year
year = '2022'

# %%
import pandas as pd

# %%
# Specify ELC course numbers
course_numbers = ['20A','20B','100A','100B','100C','15A','15B','122A','122B']

# Load instructor emails
emails = pd.read_csv('Instructor_Emails.csv',header=None,index_col=0)[1]
emails.index.name = 'Name'
emails.name = 'Email'

# %%
# Load HTML data from the schedule of classes for Econ
data = pd.read_html('Schedule of Classes.html')

# Manage
df = data[1]
df = df[(df[0].str.contains('Econ ') | df[1].str.contains('Lec'))]
df = df.reset_index(drop=True)

# Display first 20 rows
df.head(20)
# Out:
#                                               0   \
# 0                      Econ 1 INTRO TO ECONOMICS
# 1                                          62000
# 2                        Econ 12 FEDERAL RESERVE
# 3                                          62015
# 4                         Econ 13 GLOBAL ECONOMY
# 5                                          62025
# 6   Econ 15A PROB & STATS ECON I (Prerequisites)
# 7                                          62040
# 8   Econ 15B PROB &STATS ECON II (Prerequisites)
# 9                                          62055
# 10                    Econ 17 ECON APPR TO RELIG
# 11                                         62070
# 12    Econ 20A BASIC ECONOMICS I (Prerequisites)
# 13                                         62080
# 14                                         62095
# 15   Econ 20B BASIC ECONOMICS II (Prerequisites)
# 16                                         62110
# 17   Econ 23 BASIC ECON FOR ENGS (Prerequisites)
# 18                                         62125
# 19       Econ 25 ECON ACCTG DECS (Prerequisites)
#
#                                               1   \
# 0                      Econ 1 INTRO TO ECONOMICS
# 1                                            Lec
# 2                        Econ 12 FEDERAL RESERVE
# 3                                            Lec
# 4                         Econ 13 GLOBAL ECONOMY
# 5                                            Lec
# 6   Econ 15A PROB & STATS ECON I (Prerequisites)
# 7                                            Lec
# 8   Econ 15B PROB &STATS ECON II (Prerequisites)
# 9                                            Lec
# 10                    Econ 17 ECON APPR TO RELIG
# 11                                           Lec
# 12    Econ 20A BASIC ECONOMICS I (Prerequisites)
# 13                                           Lec
# 14                                           Lec
# 15   Econ 20B BASIC ECONOMICS II (Prerequisites)
# 16                                           Lec
# 17   Econ 23 BASIC ECON FOR ENGS (Prerequisites)
# 18                                           Lec
# 19       Econ 25 ECON ACCTG DECS (Prerequisites)
#
#                                               2   \
# 0                      Econ 1 INTRO TO ECONOMICS
# 1                                              A
# 2                        Econ 12 FEDERAL RESERVE
# 3                                              A
# 4                         Econ 13 GLOBAL ECONOMY
# 5                                              A
# 6   Econ 15A PROB & STATS ECON I (Prerequisites)
# 7                                              A
# 8   Econ 15B PROB &STATS ECON II (Prerequisites)
# 9                                              A
# 10                    Econ 17 ECON APPR TO RELIG
# 11                                             A
# 12    Econ 20A BASIC ECONOMICS I (Prerequisites)
# 13                                             A
# 14                                             B
# 15   Econ 20B BASIC ECONOMICS II (Prerequisites)
# 16                                             A
# 17   Econ 23 BASIC ECON FOR ENGS (Prerequisites)
# 18                                             A
# 19       Econ 25 ECON ACCTG DECS (Prerequisites)
#
#                                               3   \
# 0                      Econ 1 INTRO TO ECONOMICS
# 1                                              4
# 2                        Econ 12 FEDERAL RESERVE
# 3                                              4
# 4                         Econ 13 GLOBAL ECONOMY
# 5                                              4
# 6   Econ 15A PROB & STATS ECON I (Prerequisites)
# 7                                              4
# 8   Econ 15B PROB &STATS ECON II (Prerequisites)
# 9                                              4
# 10                    Econ 17 ECON APPR TO RELIG
# 11                                             4
# 12    Econ 20A BASIC ECONOMICS I (Prerequisites)
# 13                                             4
# 14                                             4
# 15   Econ 20B BASIC ECONOMICS II (Prerequisites)
# 16                                             4
# 17   Econ 23 BASIC ECON FOR ENGS (Prerequisites)
# 18                                             4
# 19       Econ 25 ECON ACCTG DECS (Prerequisites)
#
#                                               4   \
# 0                      Econ 1 INTRO TO ECONOMICS
# 1                                     SARRAF, G.
# 2                        Econ 12 FEDERAL RESERVE
# 3                                 RICHARDSON, G.
# 4                         Econ 13 GLOBAL ECONOMY
# 5                                     SARRAF, G.
# 6   Econ 15A PROB & STATS ECON I (Prerequisites)
# 7                                     SHIREY, P.
# 8   Econ 15B PROB &STATS ECON II (Prerequisites)
# 9                                CHERNYSHOFF, N.
# 10                    Econ 17 ECON APPR TO RELIG
# 11                                   MCBRIDE, M.
# 12    Econ 20A BASIC ECONOMICS I (Prerequisites)
# 13                            RODRIGUEZ LOPE, J.
# 14                                    TOUKAN, A.
# 15   Econ 20B BASIC ECONOMICS II (Prerequisites)
# 16                            RODRIGUEZ LOPE, J.
# 17   Econ 23 BASIC ECON FOR ENGS (Prerequisites)
# 18                            RODRIGUEZ LOPE, J.
# 19       Econ 25 ECON ACCTG DECS (Prerequisites)
#
#                                               5   \
# 0                      Econ 1 INTRO TO ECONOMICS
# 1                                            TBA
# 2                        Econ 12 FEDERAL RESERVE
# 3                              TuTh 12:30- 1:50p
# 4                         Econ 13 GLOBAL ECONOMY
# 5                                            TBA
# 6   Econ 15A PROB & STATS ECON I (Prerequisites)
# 7                                MWF 4:00- 4:50p
# 8   Econ 15B PROB &STATS ECON II (Prerequisites)
# 9                                TuTh 9:30-10:50
# 10                    Econ 17 ECON APPR TO RELIG
# 11                               TuTh 9:30-10:50
# 12    Econ 20A BASIC ECONOMICS I (Prerequisites)
# 13                                           TBA
# 14                                MWF 8:00- 8:50
# 15   Econ 20B BASIC ECONOMICS II (Prerequisites)
# 16                                           TBA
# 17   Econ 23 BASIC ECON FOR ENGS (Prerequisites)
# 18                                           TBA
# 19       Econ 25 ECON ACCTG DECS (Prerequisites)
#
#                                               6   \
# 0                      Econ 1 INTRO TO ECONOMICS
# 1                                        ON LINE
# 2                        Econ 12 FEDERAL RESERVE
# 3                                         HH 178
# 4                         Econ 13 GLOBAL ECONOMY
# 5                                        ON LINE
# 6   Econ 15A PROB & STATS ECON I (Prerequisites)
# 7                                       PSLH 100
# 8   Econ 15B PROB &STATS ECON II (Prerequisites)
# 9                                        EH 1200
# 10                    Econ 17 ECON APPR TO RELIG
# 11                                        HH 178
# 12    Econ 20A BASIC ECONOMICS I (Prerequisites)
# 13                                       ON LINE
# 14                                       HIB 100
# 15   Econ 20B BASIC ECONOMICS II (Prerequisites)
# 16                                       ON LINE
# 17   Econ 23 BASIC ECON FOR ENGS (Prerequisites)
# 18                                       ON LINE
# 19       Econ 25 ECON ACCTG DECS (Prerequisites)
#
#                                               7   \
# 0                      Econ 1 INTRO TO ECONOMICS
# 1                                            TBA
# 2                        Econ 12 FEDERAL RESERVE
# 3                      Fri, Dec 9, 10:30-12:30pm
# 4                         Econ 13 GLOBAL ECONOMY
# 5                                            TBA
# 6   Econ 15A PROB & STATS ECON I (Prerequisites)
# 7                        Wed, Dec 7, 4:00-6:00pm
# 8   Econ 15B PROB &STATS ECON II (Prerequisites)
# 9                       Thu, Dec 8, 8:00-10:00am
# 10                    Econ 17 ECON APPR TO RELIG
# 11                      Thu, Dec 8, 8:00-10:00am
# 12    Econ 20A BASIC ECONOMICS I (Prerequisites)
# 13                                           TBA
# 14                      Mon, Dec 5, 8:00-10:00am
# 15   Econ 20B BASIC ECONOMICS II (Prerequisites)
# 16                                           TBA
# 17   Econ 23 BASIC ECON FOR ENGS (Prerequisites)
# 18                                           TBA
# 19       Econ 25 ECON ACCTG DECS (Prerequisites)
#
#                                               8   \
# 0                      Econ 1 INTRO TO ECONOMICS
# 1                                            300
# 2                        Econ 12 FEDERAL RESERVE
# 3                                            120
# 4                         Econ 13 GLOBAL ECONOMY
# 5                                            448
# 6   Econ 15A PROB & STATS ECON I (Prerequisites)
# 7                                            448
# 8   Econ 15B PROB &STATS ECON II (Prerequisites)
# 9                                            332
# 10                    Econ 17 ECON APPR TO RELIG
# 11                                           136
# 12    Econ 20A BASIC ECONOMICS I (Prerequisites)
# 13                                           327
# 14                                           327
# 15   Econ 20B BASIC ECONOMICS II (Prerequisites)
# 16                                           330
# 17   Econ 23 BASIC ECON FOR ENGS (Prerequisites)
# 18                                            60
# 19       Econ 25 ECON ACCTG DECS (Prerequisites)
#
#                                               9   \
# 0                      Econ 1 INTRO TO ECONOMICS
# 1                                            299
# 2                        Econ 12 FEDERAL RESERVE
# 3                                            120
# 4                         Econ 13 GLOBAL ECONOMY
# 5                                      424 / 448
# 6   Econ 15A PROB & STATS ECON I (Prerequisites)
# 7                                            357
# 8   Econ 15B PROB &STATS ECON II (Prerequisites)
# 9                                            185
# 10                    Econ 17 ECON APPR TO RELIG
# 11                                     113 / 116
# 12    Econ 20A BASIC ECONOMICS I (Prerequisites)
# 13                                           327
# 14                                           181
# 15   Econ 20B BASIC ECONOMICS II (Prerequisites)
# 16                                           198
# 17   Econ 23 BASIC ECON FOR ENGS (Prerequisites)
# 18                                            60
# 19       Econ 25 ECON ACCTG DECS (Prerequisites)
#
#                                               10  \
# 0                      Econ 1 INTRO TO ECONOMICS
# 1                                              2
# 2                        Econ 12 FEDERAL RESERVE
# 3                                             17
# 4                         Econ 13 GLOBAL ECONOMY
# 5                                             22
# 6   Econ 15A PROB & STATS ECON I (Prerequisites)
# 7                                              1
# 8   Econ 15B PROB &STATS ECON II (Prerequisites)
# 9                                              0
# 10                    Econ 17 ECON APPR TO RELIG
# 11                                             0
# 12    Econ 20A BASIC ECONOMICS I (Prerequisites)
# 13                                            44
# 14                                             0
# 15   Econ 20B BASIC ECONOMICS II (Prerequisites)
# 16                                             0
# 17   Econ 23 BASIC ECON FOR ENGS (Prerequisites)
# 18                                             8
# 19       Econ 25 ECON ACCTG DECS (Prerequisites)
#
#                                               11  \
# 0                      Econ 1 INTRO TO ECONOMICS
# 1                                            570
# 2                        Econ 12 FEDERAL RESERVE
# 3                                            235
# 4                         Econ 13 GLOBAL ECONOMY
# 5                                            667
# 6   Econ 15A PROB & STATS ECON I (Prerequisites)
# 7                                            495
# 8   Econ 15B PROB &STATS ECON II (Prerequisites)
# 9                                            240
# 10                    Econ 17 ECON APPR TO RELIG
# 11                                           188
# 12    Econ 20A BASIC ECONOMICS I (Prerequisites)
# 13                                           581
# 14                                           214
# 15   Econ 20B BASIC ECONOMICS II (Prerequisites)
# 16                                           299
# 17   Econ 23 BASIC ECON FOR ENGS (Prerequisites)
# 18                                           106
# 19       Econ 25 ECON ACCTG DECS (Prerequisites)
#
#                                               12  \
# 0                      Econ 1 INTRO TO ECONOMICS
# 1                                              M
# 2                        Econ 12 FEDERAL RESERVE
# 3                                            NaN
# 4                         Econ 13 GLOBAL ECONOMY
# 5                                            NaN
# 6   Econ 15A PROB & STATS ECON I (Prerequisites)
# 7                                              A
# 8   Econ 15B PROB &STATS ECON II (Prerequisites)
# 9                                              A
# 10                    Econ 17 ECON APPR TO RELIG
# 11                                           NaN
# 12    Econ 20A BASIC ECONOMICS I (Prerequisites)
# 13                                             A
# 14                                             A
# 15   Econ 20B BASIC ECONOMICS II (Prerequisites)
# 16                                             A
# 17   Econ 23 BASIC ECON FOR ENGS (Prerequisites)
# 18                                       A and L
# 19       Econ 25 ECON ACCTG DECS (Prerequisites)
#
#                                               13  \
# 0                      Econ 1 INTRO TO ECONOMICS
# 1                                      Bookstore
# 2                        Econ 12 FEDERAL RESERVE
# 3                                      Bookstore
# 4                         Econ 13 GLOBAL ECONOMY
# 5                                      Bookstore
# 6   Econ 15A PROB & STATS ECON I (Prerequisites)
# 7                                      Bookstore
# 8   Econ 15B PROB &STATS ECON II (Prerequisites)
# 9                                      Bookstore
# 10                    Econ 17 ECON APPR TO RELIG
# 11                                     Bookstore
# 12    Econ 20A BASIC ECONOMICS I (Prerequisites)
# 13                                     Bookstore
# 14                                     Bookstore
# 15   Econ 20B BASIC ECONOMICS II (Prerequisites)
# 16                                     Bookstore
# 17   Econ 23 BASIC ECON FOR ENGS (Prerequisites)
# 18                                     Bookstore
# 19       Econ 25 ECON ACCTG DECS (Prerequisites)
#
#                                               14  \
# 0                      Econ 1 INTRO TO ECONOMICS
# 1                                            NaN
# 2                        Econ 12 FEDERAL RESERVE
# 3                                            NaN
# 4                         Econ 13 GLOBAL ECONOMY
# 5                                            Web
# 6   Econ 15A PROB & STATS ECON I (Prerequisites)
# 7                                            NaN
# 8   Econ 15B PROB &STATS ECON II (Prerequisites)
# 9                                            NaN
# 10                    Econ 17 ECON APPR TO RELIG
# 11                                           NaN
# 12    Econ 20A BASIC ECONOMICS I (Prerequisites)
# 13                                           NaN
# 14                                           Web
# 15   Econ 20B BASIC ECONOMICS II (Prerequisites)
# 16                                           NaN
# 17   Econ 23 BASIC ECON FOR ENGS (Prerequisites)
# 18                                           NaN
# 19       Econ 25 ECON ACCTG DECS (Prerequisites)
#
#                                               15  16
# 0                      Econ 1 INTRO TO ECONOMICS NaN
# 1                                          Waitl NaN
# 2                        Econ 12 FEDERAL RESERVE NaN
# 3                                          Waitl NaN
# 4                         Econ 13 GLOBAL ECONOMY NaN
# 5                                          Waitl NaN
# 6   Econ 15A PROB & STATS ECON I (Prerequisites) NaN
# 7                                           OPEN NaN
# 8   Econ 15B PROB &STATS ECON II (Prerequisites) NaN
# 9                                           OPEN NaN
# 10                    Econ 17 ECON APPR TO RELIG NaN
# 11                                          OPEN NaN
# 12    Econ 20A BASIC ECONOMICS I (Prerequisites) NaN
# 13                                         Waitl NaN
# 14                                          OPEN NaN
# 15   Econ 20B BASIC ECONOMICS II (Prerequisites) NaN
# 16                                          OPEN NaN
# 17   Econ 23 BASIC ECON FOR ENGS (Prerequisites) NaN
# 18                                         Waitl NaN
# 19       Econ 25 ECON ACCTG DECS (Prerequisites) NaN

# %%
# Create new blank DataFrame
new_df = pd.DataFrame(columns = ['Number','Instructor','Email'])

# Counter for adding indices to new_df
counter = 0

for i in df.index:
    if type(df.loc[i,0]) == str and df.loc[i,0].startswith('Econ '):
        number = df.loc[i,0].split(' ')[1]
        if number in course_numbers:
            
            for j in range(1,12):
                if 'Lec' in df.loc[i+j,1]:
                    instructor = df.loc[i+j,4]
                    email = emails[instructor]
                    new_df.loc[counter] = [number,instructor,email]
                    counter+=1
                    
                elif type(df.loc[i+j,0])==str and df.loc[i+j,0].startswith('Econ '):
                    break

# Display new_df
new_df
# Out:
#    Number          Instructor             Email
# 0     15A          SHIREY, P.  prshirey@uci.edu
# 1     15B     CHERNYSHOFF, N.  nchernys@uci.edu
# 2     20A  RODRIGUEZ LOPE, J.  jantonio@uci.edu
# 3     20A          TOUKAN, A.   atoukan@uci.edu
# 4     20B  RODRIGUEZ LOPE, J.  jantonio@uci.edu
# 5    100A        AGGARWAL, N.      nagg@uci.edu
# 6    100A        AGGARWAL, N.      nagg@uci.edu
# 7    100A             JHA, P.   pranjan@uci.edu
# 8    100C       ROCHETEAU, G.  grochete@uci.edu
# 9    122A            DONG, Y.       yyd@uci.edu
# 10   122B  RODRIGUEZ LOPE, J.  jantonio@uci.edu

# %%
for i in new_df.Email.unique():
    print(i)
# Out:
# prshirey@uci.edu
# nchernys@uci.edu
# jantonio@uci.edu
# atoukan@uci.edu
# nagg@uci.edu
# pranjan@uci.edu
# grochete@uci.edu
# yyd@uci.edu

# %%
# Export new_df to csv
new_df.to_csv('Current_ELC_Courses_'+quarter+'_'+str(year)+'.csv',index=False)
